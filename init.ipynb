# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting line_profiler==3.3.1
#   Downloading line_profiler-3.3.1-cp37-cp37m-manylinux2010_x86_64.whl (63 kB)
# Collecting networkx
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
# Collecting pyvis
#   Downloading pyvis-0.1.9-py3-none-any.whl (23 kB)
# Collecting Cython
#   Downloading Cython-0.29.25-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# Collecting fa2
#   Downloading fa2-0.3.5.tar.gz (435 kB)
# Collecting ForceAtlas2
#   Downloading ForceAtlas2-1.0.tar.gz (6.8 kB)
# Collecting python-louvain
#   Downloading python-louvain-0.15.tar.gz (204 kB)
# Requirement already satisfied: pandas in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 10)) (1.2.5)
# Requirement already satisfied: numpy in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 11)) (1.19.5)
# Collecting plotly==5.4.0
#   Downloading plotly-5.4.0-py2.py3-none-any.whl (25.3 MB)
# Requirement already satisfied: nltk in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 15)) (3.6.5)
# Collecting ipynb==0.5.1
#   Downloading ipynb-0.5.1-py3-none-any.whl (6.9 kB)
# Collecting wordcloud==1.8.1
#   Downloading wordcloud-1.8.1-cp37-cp37m-manylinux1_x86_64.whl (366 kB)
# Requirement already satisfied: IPython>=0.13; python_version >= "3.7" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from line_profiler==3.3.1->-r ./requirements.txt (line 1)) (7.29.0)
# Collecting jsonpickle>=1.4.1
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: jinja2>=2.9.6 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pyvis->-r ./requirements.txt (line 3)) (3.0.3)
# Requirement already satisfied: scipy in /shared-libs/python3.7/py/lib/python3.7/site-packages (from fa2->-r ./requirements.txt (line 5)) (1.7.2)
# Requirement already satisfied: tqdm in /shared-libs/python3.7/py/lib/python3.7/site-packages (from fa2->-r ./requirements.txt (line 5)) (4.62.3)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas->-r ./requirements.txt (line 10)) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pandas->-r ./requirements.txt (line 10)) (2.8.2)
# Requirement already satisfied: six in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from plotly==5.4.0->-r ./requirements.txt (line 13)) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from plotly==5.4.0->-r ./requirements.txt (line 13)) (8.0.1)
# Requirement already satisfied: joblib in /shared-libs/python3.7/py/lib/python3.7/site-packages (from nltk->-r ./requirements.txt (line 15)) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from nltk->-r ./requirements.txt (line 15)) (2021.11.10)
# Requirement already satisfied: click in /shared-libs/python3.7/py/lib/python3.7/site-packages (from nltk->-r ./requirements.txt (line 15)) (8.0.3)
# Requirement already satisfied: matplotlib in /shared-libs/python3.7/py/lib/python3.7/site-packages (from wordcloud==1.8.1->-r ./requirements.txt (line 17)) (3.4.3)
# Requirement already satisfied: pillow in /shared-libs/python3.7/py/lib/python3.7/site-packages (from wordcloud==1.8.1->-r ./requirements.txt (line 17)) (8.4.0)
# Requirement already satisfied: matplotlib-inline in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from IPython>=0.13; python_version >= "3.7"->line_profiler==3.3.1->-r ./requirements.txt (line 1)) (0.1.3)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from IPython>=0.13; python_version >= "3.7"->line_profiler==3.3.1->-r ./requirements.txt (line 1)) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from IPython>=0.13; python_version >= "3.7"->line_profiler==3.3.1->-r ./requirements.txt (line 1)) (0.17.2)
# Requirement already satisfied: traitlets>=4.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from IPython>=0.13; python_version >= "3.7"->line_profiler==3.3.1->-r ./requirements.txt (line 1)) (4.3.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from IPython>=0.13; python_version >= "3.7"->line_profiler==3.3.1->-r ./requirements.txt (line 1)) (3.0.22)
# Requirement already satisfied: pickleshare in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from IPython>=0.13; python_version >= "3.7"->line_profiler==3.3.1->-r ./requirements.txt (line 1)) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /root/venv/lib/python3.7/site-packages (from IPython>=0.13; python_version >= "3.7"->line_profiler==3.3.1->-r ./requirements.txt (line 1)) (47.1.0)
# Requirement already satisfied: pygments in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from IPython>=0.13; python_version >= "3.7"->line_profiler==3.3.1->-r ./requirements.txt (line 1)) (2.10.0)
# Requirement already satisfied: backcall in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from IPython>=0.13; python_version >= "3.7"->line_profiler==3.3.1->-r ./requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: decorator in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from IPython>=0.13; python_version >= "3.7"->line_profiler==3.3.1->-r ./requirements.txt (line 1)) (5.1.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jsonpickle>=1.4.1->pyvis->-r ./requirements.txt (line 3)) (4.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jinja2>=2.9.6->pyvis->-r ./requirements.txt (line 3)) (2.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->wordcloud==1.8.1->-r ./requirements.txt (line 17)) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib->wordcloud==1.8.1->-r ./requirements.txt (line 17)) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->wordcloud==1.8.1->-r ./requirements.txt (line 17)) (0.11.0)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pexpect>4.3; sys_platform != "win32"->IPython>=0.13; python_version >= "3.7"->line_profiler==3.3.1->-r ./requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jedi>=0.16->IPython>=0.13; python_version >= "3.7"->line_profiler==3.3.1->-r ./requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: ipython-genutils in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from traitlets>=4.2->IPython>=0.13; python_version >= "3.7"->line_profiler==3.3.1->-r ./requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: wcwidth in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython>=0.13; python_version >= "3.7"->line_profiler==3.3.1->-r ./requirements.txt (line 1)) (0.2.5)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonpickle>=1.4.1->pyvis->-r ./requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonpickle>=1.4.1->pyvis->-r ./requirements.txt (line 3)) (3.10.0.2)
# Building wheels for collected packages: fa2, ForceAtlas2, python-louvain
#   Building wheel for fa2 (setup.py): started
#   Building wheel for fa2 (setup.py): finished with status 'done'
#   Created wheel for fa2: filename=fa2-0.3.5-cp37-cp37m-linux_x86_64.whl size=151468 sha256=afc6b0c556d0c6d59e675c526f9a71bd47584d076bd6226edf254b26861cf2ac
#   Stored in directory: /root/.cache/pip/wheels/d3/b5/0a/df14cac170d872be0dd0300309b7463b5e52d936c3edce7963
#   Building wheel for ForceAtlas2 (setup.py): started
#   Building wheel for ForceAtlas2 (setup.py): finished with status 'done'
#   Created wheel for ForceAtlas2: filename=ForceAtlas2-1.0-py3-none-any.whl size=6542 sha256=184e5494cad17b1eebff2eea9efd970c2243854e4341689f0908c42356c4ba0c
#   Stored in directory: /root/.cache/pip/wheels/f8/9b/73/44a37c6817962679e6a10663477f37db07faf44ab7d7681c96
#   Building wheel for python-louvain (setup.py): started
#   Building wheel for python-louvain (setup.py): finished with status 'done'
#   Created wheel for python-louvain: filename=python_louvain-0.15-py3-none-any.whl size=9401 sha256=7ec46eaa1429878413febc5296553db2297c4531fc2471a1ff69620e54d04176
#   Stored in directory: /root/.cache/pip/wheels/c7/4c/ef/427db8777620f7fa12a6404f1527a39536a812f46a4d1044d3
# Successfully built fa2 ForceAtlas2 python-louvain
# Installing collected packages: line-profiler, networkx, jsonpickle, pyvis, Cython, fa2, ForceAtlas2, python-louvain, plotly, ipynb, wordcloud
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.3.1
#     Not uninstalling plotly at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'plotly'. No files were found to uninstall.
# Successfully installed Cython-0.29.25 ForceAtlas2-1.0 fa2-0.3.5 ipynb-0.5.1 jsonpickle-2.0.0 line-profiler-3.3.1 networkx-2.6.3 plotly-5.4.0 python-louvain-0.15 pyvis-0.1.9 wordcloud-1.8.1
# WARNING: You are using pip version 20.1.1; however, version 21.3.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=20df22e1-bd6b-4c24-9922-b8282aa7b6df' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
